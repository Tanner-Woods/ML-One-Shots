# %% [markdown]
# # ECON 441B Lab 1
#
# **Name:** Tanner Woods
#
# **UID:** 705360296

# %%
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/bus-breakdowns-delays.csv')
# df.head()

# %%
plt.figure(figsize = (10,12))
sns.countplot(df['School_Year'])
plt.title('Reported NYC School Bus Breakdowns and Delays')
plt.xlabel('School Year')
plt.ylabel('# of Incidents')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# An enormous drop in reported incidents from 2016-2017 to the subsequent years implies an improvement in safety standards or drop in incentives to report.
